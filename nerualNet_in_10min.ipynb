# %% [markdown]
# <a href="https://colab.research.google.com/github/jahanzeb-j/ML-Practice/blob/main/nerualNet_in_10min.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing tensorflow
import tensorflow as tf
#from tensorflow import keras //incase you like using keras :)

#Neural net
model = tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
model.compile(optimizer='sgd',loss='mean_squared_error')

#Input Data
num_of_flats = (1,2,3,4,5,6,7)
price_of_house = (10000,20000,30000,40000,50000,60000,70000)

#Training Neural Net
model.fit(num_of_flats,price_of_house,epochs = 500)

#Predicting the price of a house with 10 flats
print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 516ms/step - loss: 2000539392.0000
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 682423872.0000
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 233108016.0000
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 79943952.0000
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 27730498.0000
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 9928541.0000
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3856675.5000
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1783293.1250
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1072934.0000
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 827217.5000
# Epoch 11/500
# 1/1 [==============================] - 0s 3ms/step - loss: 739919.3125
# Epoch 12/500
# ...
